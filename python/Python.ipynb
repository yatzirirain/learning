# %% [markdown]
# ## For loop

# %% [markdown]
# $$
# \sum_{i=1}^n=i
# $$

# %%
n = 10
total = 0
for i in range(1,n+1):
    total+=i
print(total)
# Out:
# 55

# %% [markdown]
# $$
# n!=\prod _{i=1}^n i
# $$

# %%
n = 5
total = 1
for i in range(1,n+1):
    total*=i
print(total)
# Out:
# 120

# %%
coeffs = [1, -3, 2]   # for polynomial x^2 - 3x + 2
for idx, a in enumerate(coeffs, start=0):
    print(idx)
    print(f"Coefficient of x^{len(coeffs)-1-idx}: {a}")
# Out:
# 0
# Coefficient of x^2: 1
# 1
# Coefficient of x^1: -3
# 2
# Coefficient of x^0: 2

# %%
xs = [0, 1, 2, 3]
ys = [1, 1, 2, 3]
for x, y in zip(xs, ys):
    print(f"{x} + {y} = {x+y}")
# Out:
# 0 + 1 = 1
# 1 + 1 = 2
# 2 + 2 = 4
# 3 + 3 = 6

# %% [markdown]
# <style>
# o {color:Orange}
# </style>
# ### <o>Nested loops for matrices</o>

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
]
for i, row in enumerate(matrix):
    for j, val in enumerate(row):
        print(f"Entry ({i},{j}) = {val}")
# Out:
# Entry (0,0) = 1
# Entry (0,1) = 2
# Entry (0,2) = 3
# Entry (1,0) = 4
# Entry (1,1) = 5
# Entry (1,2) = 6

# %% [markdown]
# <style>
# o {color:Orange}
# </style>
# ### <o> 1672. Richest Customer Wealth (LEETCODE PROBLEM) </o>
#
# You are given an m x n integer grid accounts where accounts[i][j] is the amount of money the i​​​​​​​​​​​th​​​​ customer has in the j​​​​​​​​​​​th​​​​ bank. Return the wealth that the richest customer has.
#
# A customer's wealth is the amount of money they have in all their bank accounts. The richest customer is the customer that has the maximum wealth.
#
#
#
# Example 1:
#
# Input: accounts = [[1,2,3],[3,2,1]]
# Output: 6
# Explanation:
# 1st customer has wealth = 1 + 2 + 3 = 6
# 2nd customer has wealth = 3 + 2 + 1 = 6
# Both customers are considered the richest with a wealth of 6 each, so return 6.

# %%
accounts = [
    [1, 2, 3],
    [4, 5, 6],
]

wealth= [0]* len(accounts)

for i, row in enumerate(accounts):
    for j, val in enumerate(row):
        wealth[i]+=val
print(max(wealth))
# Out:
# [0, 0]
# 15

# %%
accounts = [
    [1, 2, 3],
    [4, 5, 6],
]
w=[sum(acc) for acc in accounts]
print(w)
print(max(w))
# Out:
# [6, 15]

# %%
accounts = [
    [1, 2, 3],
    [4, 5, 6],
]

w = list(map(sum, accounts))
print(w)
print(max(w))
# Out:
# [6, 15]
# 15

# %% [markdown]
# ## Conditional IF

# %%
n=15

for i in range(1,n+1):
    if i%3==0 and i%5==0: print("FizzBuzz")
    elif i%3==0: print("Fizz")
    elif i%5==0: print("Buzz")
    else: print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz

# %%
n=15
answer=[]
for i in range(1,n+1):
    if i%3==0 and i%5==0: answer.append("FizzBuzz")
    elif i%3==0: answer.append("Fizz")
    elif i%5==0: answer.append("Buzz")
    else: answer.append(str(i))

print(answer)
# Out:
# ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz']

# %%
answer=[]
n=14

# %%
class Solution:
    def setZeroes(self, matrix: List[List[int]]) -> None:
        row, col = set(), set()
        n, m = len(matrix), len(matrix[0])
        
        for i in range(n):
            for j in range(m):
                if not matrix[i][j]:
                    row.add(i)
                    col.add(j)

        for i in row:
            for j in range(m):
                matrix[i][j] = 0
        for j in col:
            for i in range(n):
                matrix[i][j] = 0
    return 0
